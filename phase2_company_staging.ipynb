# %% [markdown]
# # **Saving the Earth one row at a time**
# ## **Phase 2: Data Staging**
#
# Group 50:
# *   Annique Granchelli - 300191993
# *   Dhiaa Naas - 300170251
# *   Miten Soni - 300202194

# %%
import pandas as pd

# %%
# load company address data into dataframe
path = 'CompanyAddress.xlsx' # path to xlsx file
df = pd.read_excel(path)

# %%
# load NPRI data into another dataframe to get uniform company names
path2 = 'NPRI.csv'
df_npri = pd.read_csv(path2)
# we only care about the NPRI_ID and the Company_Name
wanted_columns = ['NPRI_ID / No_INRP', 'Company_Name / Dénomination_sociale_de_l\'entreprise']
df_npri = df_npri[wanted_columns]
df_npri.columns = [col.split(' /')[0] for col in df_npri.columns]

# %%
list(df_npri.columns)
# Out:
# ['NPRI_ID', 'Company_Name']

# %%
# delete duplicates
df_npri.drop_duplicates(keep='first', inplace=True)

# %%
df_npri
# Out:
#         NPRI_ID                                 Company_Name
# 0          6934               DEPARTMENT OF NATIONAL DEFENCE
# 1         28991                    BlackPearl Resources Inc.
# 2          2230  SUNCOR ENERGY OIL SANDS LIMITED PARTNERSHIP
# 3          2607                        Terrace Bay Pulp Inc.
# 4          1419          Howe Sound Pulp & Paper Corporation
# ...         ...                                          ...
# 958709     4442               Kraft Canada Inc.-Williamstown
# 958743     4715                               HAYES DANA INC
# 958893     3646                          Delta Faucet Canada
# 958930     3945                 BIOLAB EQUIPMENT CANADA LTD.
# 958931     3946                 BIOLAB EQUIPMENT QUEBEC LTD.
#
# [50647 rows x 2 columns]

# %% [markdown]
# ### Cleaning main dataframe

# %%
list(df.columns)
# Out:
# ['NpriID',
#  'CompanyName',
#  'Address1',
#  'Address2',
#  'City',
#  'PostalZip',
#  'ProvinceCode']

# %%
# concatenate both address columns
df['Address'] = ""
df['Address'] = df[['Address1', 'Address2']].apply(lambda x: ','.join(x.dropna()), axis=1)
df
# Out:
#        NpriID             CompanyName  \
# 0        1608     Iamgold Corporation
# 1        1608     Iamgold Corporation
# 2        1608     Iamgold Corporation
# 3        2100     Iamgold Corporation
# 4        2100     Iamgold Corporation
# ...       ...                     ...
# 35766   29606               Suite 400
# 35767   33805         BDJ Energy Inc.
# 35768    1748             Norbord inc
# 35769    3564           Anachem Ltée.
# 35770   32938  Gaudreau Environnement
#
#                                                Address1 Address2  \
# 0                                        401 Bay street      NaN
# 1                                        401 Bay street      NaN
# 2                                        401 Bay street      NaN
# 3                                        401 Bay street      NaN
# 4                                        401 Bay street      NaN
# ...                                                 ...      ...
# 35766  Tour Ouest Bureau 400 - 1111 Saint-CHarles Ouest      NaN
# 35767                            300 5 Avenue Southwest      NaN
# 35768                                               NaN      NaN
# 35769                                135 Richer  Street      NaN
# 35770                   365 de la Bonaventure Boulevard      NaN
#
#                 City PostalZip ProvinceCode  \
# 0            TORONTO    M5H2Y4           ON
# 1            TORONTO    M5H2Y4           ON
# 2            TORONTO    M5H2Y4           ON
# 3            TORONTO    M5H2Y4           ON
# 4            TORONTO    M5H2Y4           ON
# ...              ...       ...          ...
# 35766      Longueuil   J4K 5G4           QC
# 35767        CALGARY   T2P 3C4           AB
# 35768       La Sarre    J9Z2X5           QC
# 35769        LACHINE   H8R 1R4           QC
# 35770  Victoriaville   G6T 1V6           QC
#
#                                                 Address
# 0                                        401 Bay street
# 1                                        401 Bay street
# 2                                        401 Bay street
# 3                                        401 Bay street
# 4                                        401 Bay street
# ...                                                 ...
# 35766  Tour Ouest Bureau 400 - 1111 Saint-CHarles Ouest
# 35767                            300 5 Avenue Southwest
# 35768
# 35769                                135 Richer  Street
# 35770                   365 de la Bonaventure Boulevard
#
# [35771 rows x 8 columns]

# %%
# drop individual address columns and drop duplicates
df = df.drop(['Address1', 'Address2'], axis=1)
df = df.rename(columns={'PostalZip': 'Postal Code', 'ProvinceCode' : 'Province', 'CompanyName': 'Company Name'})

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
df
# Out:
#        NpriID                     Company Name           City Postal Code  \
# 0        1608              Iamgold Corporation        TORONTO      M5H2Y4
# 3        2100              Iamgold Corporation        TORONTO      M5H2Y4
# 5        8624              Iamgold Corporation        TORONTO      M5H2Y4
# 6        5095  CertainTeed Gypsum Canada, Inc.     MISSISAUGA      L5J1K4
# 7        5437  CertainTeed Gypsum Canada, Inc.     MISSISAUGA      L5J1K4
# ...       ...                              ...            ...         ...
# 35766   29606                        Suite 400      Longueuil     J4K 5G4
# 35767   33805                  BDJ Energy Inc.        CALGARY     T2P 3C4
# 35768    1748                      Norbord inc       La Sarre      J9Z2X5
# 35769    3564                    Anachem Ltée.        LACHINE     H8R 1R4
# 35770   32938           Gaudreau Environnement  Victoriaville     G6T 1V6
#
#       Province                                           Address
# 0           ON                                    401 Bay street
# 3           ON                                    401 Bay street
# 5           ON                                    401 Bay street
# 6           ON                         2424  Lakeshore Road West
# 7           ON                         2424  Lakeshore Road West
# ...        ...                                               ...
# 35766       QC  Tour Ouest Bureau 400 - 1111 Saint-CHarles Ouest
# 35767       AB                            300 5 Avenue Southwest
# 35768       QC
# 35769       QC                                135 Richer  Street
# 35770       QC                   365 de la Bonaventure Boulevard
#
# [30137 rows x 6 columns]

# %% [markdown]
# ### Extracting company dimension

# %%
company_dim_columns = ['NpriID', 'Address', 'City', 'Province', 'Postal Code']
company_dim = df[company_dim_columns].drop_duplicates(keep='first')

# %%
company_dim
# Out:
#        NpriID                                           Address  \
# 0        1608                                    401 Bay street
# 3        2100                                    401 Bay street
# 5        8624                                    401 Bay street
# 6        5095                         2424  Lakeshore Road West
# 7        5437                         2424  Lakeshore Road West
# ...       ...                                               ...
# 35766   29606  Tour Ouest Bureau 400 - 1111 Saint-CHarles Ouest
# 35767   33805                            300 5 Avenue Southwest
# 35768    1748
# 35769    3564                                135 Richer  Street
# 35770   32938                   365 de la Bonaventure Boulevard
#
#                 City Province Postal Code
# 0            TORONTO       ON      M5H2Y4
# 3            TORONTO       ON      M5H2Y4
# 5            TORONTO       ON      M5H2Y4
# 6         MISSISAUGA       ON      L5J1K4
# 7         MISSISAUGA       ON      L5J1K4
# ...              ...      ...         ...
# 35766      Longueuil       QC     J4K 5G4
# 35767        CALGARY       AB     T2P 3C4
# 35768       La Sarre       QC      J9Z2X5
# 35769        LACHINE       QC     H8R 1R4
# 35770  Victoriaville       QC     G6T 1V6
#
# [25472 rows x 5 columns]

# %%
# Do right join of company_dim and df_npri to get uniform company names across all dimensions
company_dim = pd.merge(company_dim[['NpriID', 'Address', 'City', 'Province', 'Postal Code']], df_npri[['NPRI_ID', 'Company_Name']], left_on='NpriID', right_on='NPRI_ID', how='right')

# %%
company_dim.drop(['NpriID', 'NPRI_ID'], axis=1, inplace=True)
company_dim.drop_duplicates(keep='first', inplace=True)

# %%
company_dim
# Out:
#                               Address           City Province Postal Code  \
# 0                101 Colonel By Drive         OTTAWA       ON      K1A0K2
# 1                                                NaN      NaN         NaN
# 2      700 - 444 7th Avenue Southwest        CALGARY       AB      T2P0X8
# 3                                                NaN      NaN         NaN
# 4                                      FORT MCMURRAY       AB      T9H3E3
# ...                               ...            ...      ...         ...
# 90298                                            NaN      NaN         NaN
# 90299                                            NaN      NaN         NaN
# 90300         6 - 3250 Harvester Road     BURLINGTON       ON      L7N3W9
# 90301                                            NaN      NaN         NaN
# 90302         6 - 3250 Harvester Road     BURLINGTON       ON      L7N3W9
#
#                                       Company_Name
# 0                   DEPARTMENT OF NATIONAL DEFENCE
# 1                   DEPARTMENT OF NATIONAL DEFENCE
# 2                        BlackPearl Resources Inc.
# 3      SUNCOR ENERGY OIL SANDS LIMITED PARTNERSHIP
# 4      SUNCOR ENERGY OIL SANDS LIMITED PARTNERSHIP
# ...                                            ...
# 90298                          Delta Faucet Canada
# 90299                 BIOLAB EQUIPMENT CANADA LTD.
# 90300                 BIOLAB EQUIPMENT CANADA LTD.
# 90301                 BIOLAB EQUIPMENT QUEBEC LTD.
# 90302                 BIOLAB EQUIPMENT QUEBEC LTD.
#
# [34770 rows x 5 columns]

# %%
# Drops rows with null or emtpy strings in address, city, province and postal code rows
company_dim = company_dim.dropna(subset=['Address', 'City', 'Province', 'Postal Code'])
company_dim = company_dim[(company_dim['Address'] != '') & (company_dim['City'] != '') & (company_dim['Province'] != '') & (company_dim['Postal Code'] != '')]
company_dim.reset_index(drop=True, inplace=True)

# %%
company_dim
# Out:
#                               Address           City Province Postal Code  \
# 0                101 Colonel By Drive         OTTAWA       ON      K1A0K2
# 1      700 - 444 7th Avenue Southwest        CALGARY       AB      T2P0X8
# 2                        21 Mill Road    TERRACE BAY       ON      P0T2W0
# 3            3838 Port Mellon Highway    PORT MELLON       BC     V0N 2S0
# 4                     334 AVRO Avenue  POINTE-CLAIRE       QC      H9R5W5
# ...                               ...            ...      ...         ...
# 18974                             0 -         REGINA       SK      S4P4L8
# 18975              17 Tideman Entrain    ORANGEVILLE       ON      L9W3K3
# 18976                17 Tideman Drive    ORANGEVILLE       ON      L9W3K3
# 18977         6 - 3250 Harvester Road     BURLINGTON       ON      L7N3W9
# 18978         6 - 3250 Harvester Road     BURLINGTON       ON      L7N3W9
#
#                                Company_Name
# 0            DEPARTMENT OF NATIONAL DEFENCE
# 1                 BlackPearl Resources Inc.
# 2                     Terrace Bay Pulp Inc.
# 3       Howe Sound Pulp & Paper Corporation
# 4                       LAFARGE CANADA INC.
# ...                                     ...
# 18974                    Kalium Canada Ltd.
# 18975  Les Industries Synergistics Limitee.
# 18976  Les Industries Synergistics Limitee.
# 18977          BIOLAB EQUIPMENT CANADA LTD.
# 18978          BIOLAB EQUIPMENT QUEBEC LTD.
#
# [18979 rows x 5 columns]

# %%
# generating surrogate keys for facility dimension
company_dim['company_id'] = range(1, len(company_dim)+1)
# reindex the columns
company_dim = company_dim.reindex(columns=['company_id'] + list([c for c in company_dim.columns if c!= 'company_id']))
company_dim
# Out:
#        company_id                         Address           City Province  \
# 0               1            101 Colonel By Drive         OTTAWA       ON
# 1               2  700 - 444 7th Avenue Southwest        CALGARY       AB
# 2               3                    21 Mill Road    TERRACE BAY       ON
# 3               4        3838 Port Mellon Highway    PORT MELLON       BC
# 4               5                 334 AVRO Avenue  POINTE-CLAIRE       QC
# ...           ...                             ...            ...      ...
# 18974       18975                             0 -         REGINA       SK
# 18975       18976              17 Tideman Entrain    ORANGEVILLE       ON
# 18976       18977                17 Tideman Drive    ORANGEVILLE       ON
# 18977       18978         6 - 3250 Harvester Road     BURLINGTON       ON
# 18978       18979         6 - 3250 Harvester Road     BURLINGTON       ON
#
#       Postal Code                          Company_Name
# 0          K1A0K2        DEPARTMENT OF NATIONAL DEFENCE
# 1          T2P0X8             BlackPearl Resources Inc.
# 2          P0T2W0                 Terrace Bay Pulp Inc.
# 3         V0N 2S0   Howe Sound Pulp & Paper Corporation
# 4          H9R5W5                   LAFARGE CANADA INC.
# ...           ...                                   ...
# 18974      S4P4L8                    Kalium Canada Ltd.
# 18975      L9W3K3  Les Industries Synergistics Limitee.
# 18976      L9W3K3  Les Industries Synergistics Limitee.
# 18977      L7N3W9          BIOLAB EQUIPMENT CANADA LTD.
# 18978      L7N3W9          BIOLAB EQUIPMENT QUEBEC LTD.
#
# [18979 rows x 6 columns]

# %%
company_dim.to_csv('company_dimension.csv')
